# %%
import pandas as pd

# %%
df=pd.read_csv('churn_dataset.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df['TotalCharges'].dtypes
# Out:
# dtype('O')

# %%
import pandas as pd


# Convert 'TotalCharges' column from object to float
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df['TotalCharges'].dtypes
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df['TotalCharges'].min()
# Out:
# 18.8

# %%
df['TotalCharges'].max()
# Out:
# 8684.8

# %%
df['TotalCharges'].mean()
# Out:
# 2283.3004408418697

# %%
df['TotalCharges'].median()
# Out:
# 1397.475

# %%
df['TotalCharges'].std()
# Out:
# 2266.7713618831453

# %%
df['TotalCharges'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['TotalCharges'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from scipy import stats
import matplotlib.pyplot as plt

# %%
stats.probplot(df['TotalCharges'],dist='uniform',plot=plt)
plt.grid()

# %%
df['TotalCharges']=df['TotalCharges'].fillna(df['TotalCharges'].median())

# %%
df['TotalCharges'].isnull().sum()
# Out:
# 0

# %%
print(df['tenure'].min())
print(df['tenure'].max())
print(df['tenure'].mean())
print(df['tenure'].median())
print(df['tenure'].std())
# Out:
# 0
# 72
# 32.37114865824223
# 29.0
# 24.55948102309423

# %%
# Univariate Analysis
df['tenure'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['tenure'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
print(df['MonthlyCharges'].min())
print(df['MonthlyCharges'].max())
print(df['MonthlyCharges'].mean())
print(df['MonthlyCharges'].median())
print(df['MonthlyCharges'].std())
# Out:
# 18.25
# 118.75
# 64.76169246059922
# 70.35
# 30.09004709767854

# %%
df['MonthlyCharges'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['MonthlyCharges'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
print(df['SeniorCitizen'].min())
print(df['SeniorCitizen'].max())
print(df['SeniorCitizen'].mean())
print(df['SeniorCitizen'].median())
print(df['SeniorCitizen'].std())
# Out:
# 0
# 1
# 0.1621468124378816
# 0.0
# 0.36861160561002687

# %%
df['SeniorCitizen'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#Univariate Analysis Categorical

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Partner'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Dependents'].value_counts()
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
df['Dependents'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['PhoneService'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['MultipleLines'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['InternetService'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Contract'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['PaymentMethod'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Churn'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bivariate Analysis

# %%
#NUM vs NUM

# %%
df['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
df.plot(kind='scatter',x='tenure',y='MonthlyCharges')
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='MonthlyCharges'>

# %%
df.plot(kind='scatter',x='SeniorCitizen',y='TotalCharges')
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='TotalCharges'>

# %%
df.plot(kind='scatter',x='SeniorCitizen',y='tenure')
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='tenure'>

# %%
#NUM VS CAT

# %%
df.boxplot(by='Partner',column='MonthlyCharges')
# Out:
# <AxesSubplot:title={'center':'MonthlyCharges'}, xlabel='Partner'>

# %%
df.boxplot(by='gender',column='MonthlyCharges')
# Out:
# <AxesSubplot:title={'center':'MonthlyCharges'}, xlabel='gender'>

# %%
df.boxplot(by='PaymentMethod',column='MonthlyCharges')
# Out:
# <AxesSubplot:title={'center':'MonthlyCharges'}, xlabel='PaymentMethod'>

# %%
df.boxplot(by='PaymentMethod',column='TotalCharges')
# Out:
# <AxesSubplot:title={'center':'TotalCharges'}, xlabel='PaymentMethod'>

# %%
df.boxplot(by='InternetService',column='TotalCharges')
# Out:
# <AxesSubplot:title={'center':'TotalCharges'}, xlabel='InternetService'>

# %%
df.boxplot(by='Contract',column='TotalCharges')
# Out:
# <AxesSubplot:title={'center':'TotalCharges'}, xlabel='Contract'>

# %%
df.boxplot(by='Churn',column='TotalCharges')
# Out:
# <AxesSubplot:title={'center':'TotalCharges'}, xlabel='Churn'>

# %%
df.boxplot(by='Churn',column='MonthlyCharges')
# Out:
# <AxesSubplot:title={'center':'MonthlyCharges'}, xlabel='Churn'>

# %%
df.boxplot(by='Churn',column='tenure')
# Out:
# <AxesSubplot:title={'center':'tenure'}, xlabel='Churn'>

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
X=df[['gender','tenure', 'PhoneService','Contract','MonthlyCharges', 'TotalCharges']]
y=df['Churn']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=100)

# %%
X_train.head()
# Out:
#       gender  tenure PhoneService        Contract  MonthlyCharges  \
# 6630    Male      16          Yes  Month-to-month           78.75
# 7013  Female      40          Yes  Month-to-month           93.40
# 2224    Male      17          Yes  Month-to-month           76.45
# 6580  Female      49          Yes        One year           78.00
# 1501    Male      13          Yes        Two year           19.95
#
#       TotalCharges
# 6630       1218.25
# 7013       3756.40
# 2224       1233.40
# 6580       3824.20
# 1501        243.65

# %%
print(X_train.shape, y_train.shape)

print(X_test.shape, y_test.shape)
# Out:
# (5282, 6) (5282,)
# (1761, 6) (1761,)

# %%
X_train.dtypes
# Out:
# gender             object
# tenure              int64
# PhoneService       object
# Contract           object
# MonthlyCharges    float64
# TotalCharges      float64
# dtype: object

# %%
X_train_num=X_train.select_dtypes(include=['int64','float64'])
X_train_num.head()
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 6630      16           78.75       1218.25
# 7013      40           93.40       3756.40
# 2224      17           76.45       1233.40
# 6580      49           78.00       3824.20
# 1501      13           19.95        243.65

# %%
X_train_cat=X_train.select_dtypes(include=['object'])
X_train_cat.head()
# Out:
#       gender PhoneService        Contract
# 6630    Male          Yes  Month-to-month
# 7013  Female          Yes  Month-to-month
# 2224    Male          Yes  Month-to-month
# 6580  Female          Yes        One year
# 1501    Male          Yes        Two year

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_num_rescaled=pd.DataFrame(scaler.fit_transform(X_train_num), columns = X_train_num.columns, 
                                    index = X_train_num.index)

# %%
X_train_num_rescaled.head()
# Out:
#         tenure  MonthlyCharges  TotalCharges
# 6630 -0.669552        0.471732     -0.471643
# 7013  0.305416        0.957819      0.649818
# 2224 -0.628928        0.395418     -0.464949
# 6580  0.671028        0.446847      0.679775
# 1501 -0.791422       -1.479251     -0.902262

# %%
X_train_num.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  5282.000000     5282.000000   5282.000000
# mean     32.481825       64.532630   2285.697709
# std      24.618547       30.141497   2263.467586
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.062500    402.662500
# 50%      29.000000       70.250000   1397.475000
# 75%      56.000000       89.700000   3808.150000
# max      72.000000      118.650000   8670.100000

# %%
import numpy as np
print("Number of Numerical Features:", scaler.n_features_in_)
print("Mean of each column:", scaler.mean_)
print("Std of each column:", np.sqrt(scaler.var_))
# Out:
# Number of Numerical Features: 3
# Mean of each column: [  32.48182507   64.53262969 2285.6977092 ]
# Std of each column: [  24.61621647   30.13864334 2263.25331323]

# %% [markdown]
# # Applying OneHotEncoding on Categorical Columns

# %%
#customerID	gender	PhoneService	Contract

#X_train_cat['customerID'].value_counts()

# %%
X_train_cat['gender'].value_counts()
# Out:
# Male      2646
# Female    2636
# Name: gender, dtype: int64

# %%
X_train_cat['PhoneService'].value_counts()
# Out:
# Yes    4774
# No      508
# Name: PhoneService, dtype: int64

# %%
X_train_cat['Contract'].value_counts()
# Out:
# Month-to-month    2868
# Two year          1300
# One year          1114
# Name: Contract, dtype: int64

# %%
# OneHotEncoding the categorical features

from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_cat_ohe = pd.DataFrame(encoder.fit_transform(X_train_cat), 
                               columns=encoder.get_feature_names_out(X_train_cat.columns), 
                               index = X_train_cat.index)

X_train_cat_ohe.head()
# Out:
# C:\Users\Pintoo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#       gender_Male  PhoneService_Yes  Contract_One year  Contract_Two year
# 6630          1.0               1.0                0.0                0.0
# 7013          0.0               1.0                0.0                0.0
# 2224          1.0               1.0                0.0                0.0
# 6580          0.0               1.0                1.0                0.0
# 1501          1.0               1.0                0.0                1.0

# %%
X_train_transformed = pd.concat([X_train_num_rescaled, X_train_cat_ohe], axis=1)

X_train_transformed.head()
# Out:
#         tenure  MonthlyCharges  TotalCharges  gender_Male  PhoneService_Yes  \
# 6630 -0.669552        0.471732     -0.471643          1.0               1.0
# 7013  0.305416        0.957819      0.649818          0.0               1.0
# 2224 -0.628928        0.395418     -0.464949          1.0               1.0
# 6580  0.671028        0.446847      0.679775          0.0               1.0
# 1501 -0.791422       -1.479251     -0.902262          1.0               1.0
#
#       Contract_One year  Contract_Two year
# 6630                0.0                0.0
# 7013                0.0                0.0
# 2224                0.0                0.0
# 6580                1.0                0.0
# 1501                0.0                1.0

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1761 entries, 4880 to 3368
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          1761 non-null   object
#  1   tenure          1761 non-null   int64
#  2   PhoneService    1761 non-null   object
#  3   Contract        1761 non-null   object
#  4   MonthlyCharges  1761 non-null   float64
#  5   TotalCharges    1761 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 96.3+ KB

# %%
X_test_num=X_test.select_dtypes(include=['int64','float64'])
X_test_num.head()
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 4880      50           20.55       1067.65
# 1541      72           19.85       1434.10
# 1289      63           68.80       4111.35
# 5745      61           24.20       1445.20
# 4873       7           19.30        144.95

# %%
X_test_cat=X_test.select_dtypes(include=['object'])
X_test_cat.head()
# Out:
#       gender PhoneService        Contract
# 4880    Male          Yes        Two year
# 1541    Male          Yes        Two year
# 1289    Male          Yes        One year
# 5745  Female          Yes        Two year
# 4873  Female          Yes  Month-to-month

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_test_num_rescaled=pd.DataFrame(scaler.fit_transform(X_test_num), columns = X_test_num.columns, 
                                    index = X_test_num.index)

# %%
X_test_num_rescaled.head()
# Out:
#         tenure  MonthlyCharges  TotalCharges
# 4880  0.736749       -1.500390     -0.529777
# 1541  1.639184       -1.523782     -0.368390
# 1289  1.270006        0.111989      0.810688
# 5745  1.187967       -1.378418     -0.363501
# 4873 -1.027102       -1.542162     -0.936139

# %%
# OneHotEncoding the categorical features

from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# colun names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

X_test_cat_ohe = pd.DataFrame(encoder.fit_transform(X_test_cat), 
                               columns=encoder.get_feature_names_out(X_test_cat.columns), 
                               index = X_test_cat_ohe.index)

X_test_cat_ohe.head()
# Out:
# C:\Users\Pintoo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22984\2690251427.py in <module>
#      10 X_test_cat_ohe = pd.DataFrame(encoder.fit_transform(X_test_cat),
#      11                                columns=encoder.get_feature_names_out(X_test_cat.columns),
# ---> 12                                index = X_test_cat_ohe.index)
#      13
#      14 X_test_cat_ohe.head()
#
# NameError: name 'X_test_cat_ohe' is not defined

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# Convert DataFrame to numpy array
X_test_cat_array = X_test_cat.values

# Apply one-hot encoding
X_test_cat_ohe_array = encoder.fit_transform(X_test_cat_array)

# Create a new DataFrame with column names
X_test_cat_ohe = pd.DataFrame(X_test_cat_ohe_array, 
                              columns=encoder.get_feature_names_out(X_test_cat.columns), 
                              index=X_test_cat.index)

X_test_cat_ohe.head()
# Out:
# C:\Users\Pintoo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#       gender_Male  PhoneService_Yes  Contract_One year  Contract_Two year
# 4880          1.0               1.0                0.0                1.0
# 1541          1.0               1.0                0.0                1.0
# 1289          1.0               1.0                1.0                0.0
# 5745          0.0               1.0                0.0                1.0
# 4873          0.0               1.0                0.0                0.0

# %% [markdown]
# # Concatinating the Encoded Categorical Features and Rescaled Numerical Features:

# %%
X_test_transformed = pd.concat([X_test_num_rescaled, X_test_cat_ohe], axis=1)

X_test_transformed.head()
# Out:
#         tenure  MonthlyCharges  TotalCharges  gender_Male  PhoneService_Yes  \
# 4880  0.736749       -1.500390     -0.529777          1.0               1.0
# 1541  1.639184       -1.523782     -0.368390          1.0               1.0
# 1289  1.270006        0.111989      0.810688          1.0               1.0
# 5745  1.187967       -1.378418     -0.363501          0.0               1.0
# 4873 -1.027102       -1.542162     -0.936139          0.0               1.0
#
#       Contract_One year  Contract_Two year
# 4880                0.0                1.0
# 1541                0.0                1.0
# 1289                1.0                0.0
# 5745                0.0                1.0
# 4873                0.0                0.0

# %%
y_test.head()
# Out:
# 4880    No
# 1541    No
# 1289    No
# 5745    No
# 4873    No
# Name: Churn, dtype: object

# %%
# Assuming 'No' represents the negative class and 'Yes' represents the positive class
y_train_numeric = y_train.replace({'No': 0, 'Yes': 1})

regressor.fit(X_train_transformed, y_train_numeric)
# Out:
# LogisticRegression()

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_transformed, y_train_numeric)
# Out:
# LogisticRegression()

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %%
# Assuming you have transformed test data as X_test_transformed
y_pred = classifier.predict(X_test_transformed)

# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test_numeric, y_pred)
precision = precision_score(y_test_numeric, y_pred)
recall = recall_score(y_test_numeric, y_pred)
f1 = f1_score(y_test_numeric, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.7773992049971608
# Precision: 0.6321525885558583
# Recall: 0.47443762781186094
# F1 Score: 0.5420560747663552

# %%
from sklearn import metrics

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7666098807495741

# %% [markdown]
# # Knn

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7666098807495741

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7081203861442362

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.75809199318569
